# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishika1702/Day-1-Assignment/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randn, randint, uniform, sample

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
print ('Matplotlib version: ', mpl.__version__ ) # >= 2.0.0q
# Out:
# Matplotlib version:  3.2.2

# %%
x=np.arange(0,10)
y=x*x

# %%
plt.plot(x,y,'ro--', linewidth=1, markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
plt.plot(a,b,'ro--', linewidth=1, markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(a,b,'ro--', linewidth=1, markersize=5)
plt.title('Line Plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
days = [1,2,3,4,5,6,7]
sales_1 = [160,150,140,145,175,165,180]
sales_2 = [70,90,160,150,140,145,175]

# %%
plt.plot(days,sales_1,'ro--', linewidth=1, markersize=5)
plt.title('sales trend in company 1 ')
plt.xlabel('days')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.plot(days,sales_2,'ro--', linewidth=1, markersize=5)
plt.title('sales trend in company 2 ')
plt.xlabel('days')
plt.ylabel('sales ')
# Out:
# Text(0, 0.5, 'sales ')

# %%
x=[1,2,3,4]
y=[4,3,2,1]
y2=[10,20,30,40]
y3=[40,30,20,10]
y4=[1,2,1,2]
y5=[40,70,90,70]

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'ro--')
plt.subplot(2,2,2)
plt.plot(y2,y3,'g*--')
plt.subplot(2,2,3)
plt.plot(y4,y5,'bo--')
